# %%
import pandas as pd
from core_util.proxy import enable_proxy
import requests
enable_proxy()

# %%
day_ahead_clearing_price = pd.read_html('https://www.ercot.com/content/cdr/html/dam_mcpc.html')[0].set_index('Hour Ending') #clearing price
day_ahead_settlepoint_price = pd.read_html('https://www.ercot.com/content/cdr/html/dam_spp.html')[0].set_index('Hour Ending') #DAM Settlement Point Prices Display

# %%
day_ahead_clearing_price.plot(figsize=[20,10])
# Out:
# <Axes: xlabel='Hour Ending'>

# %%
day_ahead_settlepoint_price.plot(figsize=[20,10])
# Out:
# <Axes: xlabel='Hour Ending'>
